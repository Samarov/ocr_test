# %%
from PIL import Image
pic = Image.open('test.png')
pic
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=319x333 at 0x7F36106CD310>

# %%
from pytesseract import image_to_string

# %%
custom_config = r'--oem 3 --psm 4'

# %%
print (image_to_string(pic, lang='eng+rus', config=custom_config))
# Out:
# Многие знают, что АВВУУ занимается
# обработкой и извлечением данных из
# разных документов. Но у наших
# продуктов есть и другие интересные
# возможности. В частности, с помощью
# решения АВВУУ имешдеги Зеагсй
# можно быстро и удобно искать
# информацию по смыслу в электронных
# документах из корпоративных систем.
# Этим уже пользуются крупные.
# российские компании, например,
# производитель ракетных двигателей до
# «НПО Энергомаш».

# %%
import textract

# %%
text = textract.process('test.png', language='eng+rus').decode('UTF-8')
text
# Out:
# 'Многие знают, что АВВУУ занимается\nобработкой и извлечением данных из\nразных документов. Но у наших\nпродуктов есть и другие интересные\nвозможности. В частности, с помощью\nрешения АВВУУ имешдеги Зеагсй\nможно быстро и удобно искать\nинформацию по смыслу в электронных\nдокументах из корпоративных систем.\nЭтим уже пользуются крупные.\nроссийские компании, например,\nпроизводитель ракетных двигателей до\n«НПО Энергомаш».\n\x0c'
